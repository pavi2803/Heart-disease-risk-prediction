# %%
import pandas as pd
import math

import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("C:/Users/Pavithra/Documents/DATASETS/diabetes.csv")

# %%
my_data = data.head(20)

# %%
user_data = [150,100]

# %%
my_data.count()
# Out:
# Pregnancies                 20
# Glucose                     20
# BloodPressure               20
# SkinThickness               20
# Insulin                     20
# BMI                         20
# DiabetesPedigreeFunction    20
# Age                         20
# Outcome                     20
# dtype: int64

# %%
my_data
# Out:
#     Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0             6      148             72             35        0  33.6
# 1             1       85             66             29        0  26.6
# 2             8      183             64              0        0  23.3
# 3             1       89             66             23       94  28.1
# 4             0      137             40             35      168  43.1
# 5             5      116             74              0        0  25.6
# 6             3       78             50             32       88  31.0
# 7            10      115              0              0        0  35.3
# 8             2      197             70             45      543  30.5
# 9             8      125             96              0        0   0.0
# 10            4      110             92              0        0  37.6
# 11           10      168             74              0        0  38.0
# 12           10      139             80              0        0  27.1
# 13            1      189             60             23      846  30.1
# 14            5      166             72             19      175  25.8
# 15            7      100              0              0        0  30.0
# 16            0      118             84             47      230  45.8
# 17            7      107             74              0        0  29.6
# 18            1      103             30             38       83  43.3
# 19            1      115             70             30       96  34.6
#
#     DiabetesPedigreeFunction  Age  Outcome
# 0                      0.627   50        1
# 1                      0.351   31        0
# 2                      0.672   32        1
# 3                      0.167   21        0
# 4                      2.288   33        1
# 5                      0.201   30        0
# 6                      0.248   26        1
# 7                      0.134   29        0
# 8                      0.158   53        1
# 9                      0.232   54        1
# 10                     0.191   30        0
# 11                     0.537   34        1
# 12                     1.441   57        0
# 13                     0.398   59        1
# 14                     0.587   51        1
# 15                     0.484   32        1
# 16                     0.551   31        1
# 17                     0.254   31        1
# 18                     0.183   33        0
# 19                     0.529   32        1

# %%
k_sqrt = math.sqrt(20)

# %%
print(k_sqrt)
# Out:
# 4.47213595499958

# %%
k=5

# %%
print(k)
# Out:
# 5

# %%
data_arr=[]
dist_arr = []

# %%
my_data.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.181410      -0.058186      -0.806660
# Glucose                      0.181410  1.000000       0.219686       0.016168
# BloodPressure               -0.058186  0.219686       1.000000       0.008259
# SkinThickness               -0.806660  0.016168       0.008259       1.000000
# Insulin                     -0.486759  0.553790       0.036305       0.461601
# BMI                         -0.386041 -0.072565      -0.314031       0.450973
# DiabetesPedigreeFunction    -0.039599  0.209934      -0.041423       0.103832
# Age                          0.182946  0.667874       0.308379       0.043219
# Outcome                     -0.015099  0.452664       0.098262       0.209843
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.486759 -0.386041                 -0.039599
# Glucose                   0.553790 -0.072565                  0.209934
# BloodPressure             0.036305 -0.314031                 -0.041423
# SkinThickness             0.461601  0.450973                  0.103832
# Insulin                   1.000000  0.118807                 -0.023130
# BMI                       0.118807  1.000000                  0.236690
# DiabetesPedigreeFunction -0.023130  0.236690                  1.000000
# Age                       0.491582 -0.383225                  0.174482
# Outcome                   0.316934 -0.077424                  0.191270
#
#                                Age   Outcome
# Pregnancies               0.182946 -0.015099
# Glucose                   0.667874  0.452664
# BloodPressure             0.308379  0.098262
# SkinThickness             0.043219  0.209843
# Insulin                   0.491582  0.316934
# BMI                      -0.383225 -0.077424
# DiabetesPedigreeFunction  0.174482  0.191270
# Age                       1.000000  0.289022
# Outcome                   0.289022  1.000000

# %%
sns.heatmap(my_data.corr());

# %%
new_data = my_data.drop('SkinThickness',axis=1)

# %%
new_data1 = new_data.drop("Pregnancies",axis = 1)
new_data2 = new_data1.drop("BloodPressure",axis = 1)
new_data3 = new_data2.drop("BMI",axis = 1)
new_data4 = new_data3.drop("Age",axis = 1)
new_data5 = new_data4.drop("DiabetesPedigreeFunction",axis = 1)

# %%
mynewdata=new_data5.drop('Outcome',axis=1)

# %%
new_data5
# Out:
#     Glucose  Insulin  Outcome
# 0       148        0        1
# 1        85        0        0
# 2       183        0        1
# 3        89       94        0
# 4       137      168        1
# 5       116        0        0
# 6        78       88        1
# 7       115        0        0
# 8       197      543        1
# 9       125        0        1
# 10      110        0        0
# 11      168        0        1
# 12      139        0        0
# 13      189      846        1
# 14      166      175        1
# 15      100        0        1
# 16      118      230        1
# 17      107        0        1
# 18      103       83        0
# 19      115       96        1

# %%
mynewdata
# Out:
#     Glucose  Insulin
# 0       148        0
# 1        85        0
# 2       183        0
# 3        89       94
# 4       137      168
# 5       116        0
# 6        78       88
# 7       115        0
# 8       197      543
# 9       125        0
# 10      110        0
# 11      168        0
# 12      139        0
# 13      189      846
# 14      166      175
# 15      100        0
# 16      118      230
# 17      107        0
# 18      103       83
# 19      115       96

# %%
columns = list(mynewdata)

# %%
print(columns)
# Out:
# ['Glucose', 'Insulin']

# %%
for j in range(0,20):
    for i in columns:
        print(mynewdata[i][j])
        elem = mynewdata[i][j]
        data_arr.append(elem)
    print(data_arr)
    
    dist = ( (user_data[0]-data_arr[0]) **2 + (user_data[1]-data_arr[1])**2 ) **0.5
    dist_arr.append(dist)
    data_arr=[]
# Out:
# 148
# 0
# [148, 0]
# 85
# 0
# [85, 0]
# 183
# 0
# [183, 0]
# 89
# 94
# [89, 94]
# 137
# 168
# [137, 168]
# 116
# 0
# [116, 0]
# 78
# 88
# [78, 88]
# 115
# 0
# [115, 0]
# 197
# 543
# [197, 543]
# 125
# 0
# [125, 0]
# 110
# 0
# [110, 0]
# 168
# 0
# [168, 0]
# 139
# 0
# [139, 0]
# 189
# 846
# [189, 846]
# 166
# 175
# [166, 175]
# 100
# 0
# [100, 0]
# 118
# 230
# [118, 230]
# 107
# 0
# [107, 0]
# 103
# 83
# [103, 83]
# 115
# 96
# [115, 96]

# %%
dist_arr
# Out:
# [100.0199980003999,
#  119.26860441876563,
#  105.30432089900205,
#  61.29437168288782,
#  69.2314957226839,
#  105.62196741208714,
#  72.99315036357864,
#  105.94810050208545,
#  445.4862511907635,
#  103.07764064044152,
#  107.70329614269008,
#  101.6070863670443,
#  100.60318086422517,
#  747.0187413980991,
#  76.68767828015137,
#  111.80339887498948,
#  133.88054376943649,
#  108.85311203635843,
#  49.9799959983992,
#  35.22782990761707]

# %%
result = pd.DataFrame(dist_arr)

# %%
result['Glucose'] = mynewdata['Glucose']

# %%
result['Insulin'] = mynewdata['Insulin']
result['Diabetes'] = new_data5['Outcome']

# %%
result
# Out:
#              0  Glucose  Insulin  Diabetes
# 0   100.019998      148        0         1
# 1   119.268604       85        0         0
# 2   105.304321      183        0         1
# 3    61.294372       89       94         0
# 4    69.231496      137      168         1
# 5   105.621967      116        0         0
# 6    72.993150       78       88         1
# 7   105.948101      115        0         0
# 8   445.486251      197      543         1
# 9   103.077641      125        0         1
# 10  107.703296      110        0         0
# 11  101.607086      168        0         1
# 12  100.603181      139        0         0
# 13  747.018741      189      846         1
# 14   76.687678      166      175         1
# 15  111.803399      100        0         1
# 16  133.880544      118      230         1
# 17  108.853112      107        0         1
# 18   49.979996      103       83         0
# 19   35.227830      115       96         1

# %%
result.nsmallest(5,[0])
# Out:
#             0  Glucose  Insulin  Diabetes
# 19  35.227830      115       96         1
# 18  49.979996      103       83         0
# 3   61.294372       89       94         0
# 4   69.231496      137      168         1
# 6   72.993150       78       88         1
